# %% [markdown]
# # Data Sources

# %% [markdown]
# The following datasources were collected from the following sources:
#
# - [**Spatially-resolved transcriptomics analyses of invasive fronts in solid tumors, Accession Number: OEP000321**](https://www.biorxiv.org/content/10.1101/2021.10.21.465135v1)
#   - from the national genomics datacenter (NGDC) at the University of California, San Francisco (UCSF). Paper link
#   - Link: https://ngdc.cncb.ac.cn/openlb/publication/OLB-BRV-10.1101/2021.10.21.465135v1

# %% [markdown]
# ---
# - [**Spatial multiomics map of trophoblast development in early pregnancy.**](https://www.nature.com/articles/s41586-023-05869-0#data-availability)
#   - Link: http://www.ebi.ac.uk/arrayexpress/experiments/E-MTAB-12421/ - this dataset should contain our scRNA-seq and snRNA-seq data of primary tissue.
#   - Link: http://www.ebi.ac.uk/arrayexpress/experiments/E-MTAB-12698/ - this dataset should contain spatial transcriptomics data of primary tissue via VISIUM.
#   - Link: http://www.ebi.ac.uk/arrayexpress/experiments/E-MTAB-6701/ - this dataset should contain an external scRNA-seq dtatset of the first trimerster human decidual-placental interface, via ArrayExpress tech.
